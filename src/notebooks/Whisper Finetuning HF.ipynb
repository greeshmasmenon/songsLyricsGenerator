# %%
# !pip uninstall -y transformers datasets 
# !pip install audiomentations
# !pip install git+https://github.com/huggingface/datasets
# !pip install git+https://github.com/huggingface/transformers
# !pip install librosa soundfile
# !pip install "evaluate>=0.3.0"
# !pip install jiwer
# !pip install more-itertools
# !pip install wandb
# !pip install bitsandbytes
# !pip install "bokeh<2.5"
# !pip install "holoviews[recommended]"
! pip install evaluate
# Out:
# Found existing installation: transformers 4.32.0.dev0
# Uninstalling transformers-4.32.0.dev0:
#   Successfully uninstalled transformers-4.32.0.dev0
# Found existing installation: datasets 2.14.1.dev0
# Uninstalling datasets-2.14.1.dev0:
#   Successfully uninstalled datasets-2.14.1.dev0
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: audiomentations in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (0.31.0)
# Requirement already satisfied: numpy>=1.13.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from audiomentations) (1.23.5)
# Requirement already satisfied: librosa!=0.10.0,<0.11.0,>=0.8.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from audiomentations) (0.10.0.post1)
# Requirement already satisfied: scipy<2,>=1.3.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from audiomentations) (1.10.1)
# Requirement already satisfied: soxr<1.0.0,>=0.3.2 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from audiomentations) (0.3.4)
# Requirement already satisfied: audioread>=2.1.9 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (3.0.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (1.3.1)
# Requirement already satisfied: decorator>=4.3.0 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (0.56.4)
# Requirement already satisfied: soundfile>=0.12.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (1.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (4.7.1)
# Requirement already satisfied: lazy-loader>=0.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (0.1)
# Requirement already satisfied: msgpack>=1.0 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (1.0.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from numba>=0.51.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (0.39.1)
# Requirement already satisfied: setuptools in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from numba>=0.51.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (50.3.0)
# Requirement already satisfied: importlib-metadata in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from numba>=0.51.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (6.0.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from pooch>=1.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (3.1.1)
# Requirement already satisfied: packaging>=20.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from pooch>=1.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (23.1)
# Requirement already satisfied: requests>=2.19.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from pooch>=1.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (2.28.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from scikit-learn>=0.20.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from soundfile>=0.12.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (1.15.1)
# Requirement already satisfied: pycparser in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (2020.6.20)
# Requirement already satisfied: zipp>=0.5 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from importlib-metadata->numba>=0.51.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (3.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting git+https://github.com/huggingface/datasets
#   Cloning https://github.com/huggingface/datasets to /tmp/pip-req-build-624hh4nr
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/datasets /tmp/pip-req-build-624hh4nr
#   Resolved https://github.com/huggingface/datasets to commit b0177910b32712f28d147879395e511207e39958
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.17 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets==2.14.1.dev0) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets==2.14.1.dev0) (12.0.1)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets==2.14.1.dev0) (0.3.6)
# Requirement already satisfied: pandas in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets==2.14.1.dev0) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets==2.14.1.dev0) (2.28.2)
# Requirement already satisfied: tqdm>=4.62.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets==2.14.1.dev0) (4.65.0)
# Requirement already satisfied: xxhash in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets==2.14.1.dev0) (3.2.0)
# Requirement already satisfied: multiprocess in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets==2.14.1.dev0) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets==2.14.1.dev0) (2023.6.0)
# Requirement already satisfied: aiohttp in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets==2.14.1.dev0) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets==2.14.1.dev0) (0.16.4)
# Requirement already satisfied: packaging in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets==2.14.1.dev0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets==2.14.1.dev0) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from aiohttp->datasets==2.14.1.dev0) (20.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from aiohttp->datasets==2.14.1.dev0) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from aiohttp->datasets==2.14.1.dev0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from aiohttp->datasets==2.14.1.dev0) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from aiohttp->datasets==2.14.1.dev0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from aiohttp->datasets==2.14.1.dev0) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from aiohttp->datasets==2.14.1.dev0) (1.3.1)
# Requirement already satisfied: filelock in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.1.dev0) (3.0.12)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets==2.14.1.dev0) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from requests>=2.19.0->datasets==2.14.1.dev0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from requests>=2.19.0->datasets==2.14.1.dev0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from requests>=2.19.0->datasets==2.14.1.dev0) (2020.6.20)
# Requirement already satisfied: python-dateutil>=2.8.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from pandas->datasets==2.14.1.dev0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from pandas->datasets==2.14.1.dev0) (2020.1)
# Requirement already satisfied: six>=1.5 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->datasets==2.14.1.dev0) (1.15.0)
# Building wheels for collected packages: datasets
#   Building wheel for datasets (pyproject.toml) ... done
#   Created wheel for datasets: filename=datasets-2.14.1.dev0-py3-none-any.whl size=492371 sha256=ff2fc52f0eb72939d079902b8038f92ffd8212533daa29a2e18d1486cb21d9c1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tja2sjul/wheels/fa/94/e3/3c713e74271e453a93a303d5095aca41e03828d80af1b3742c
# Successfully built datasets
# Installing collected packages: datasets
# Successfully installed datasets-2.14.1.dev0
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-fc0hkjip
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-fc0hkjip
#   Resolved https://github.com/huggingface/transformers to commit a5cc30d72ae2dc19af534e4b35c986cc28db1275
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from transformers==4.32.0.dev0) (3.0.12)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from transformers==4.32.0.dev0) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from transformers==4.32.0.dev0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from transformers==4.32.0.dev0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from transformers==4.32.0.dev0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from transformers==4.32.0.dev0) (2023.6.3)
# Requirement already satisfied: requests in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from transformers==4.32.0.dev0) (2.28.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from transformers==4.32.0.dev0) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from transformers==4.32.0.dev0) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from transformers==4.32.0.dev0) (4.65.0)
# Requirement already satisfied: fsspec in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.32.0.dev0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.32.0.dev0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from requests->transformers==4.32.0.dev0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from requests->transformers==4.32.0.dev0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from requests->transformers==4.32.0.dev0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from requests->transformers==4.32.0.dev0) (2020.6.20)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.32.0.dev0-py3-none-any.whl size=7442167 sha256=131294c566fbcc940e3742dc6d46fc5b7e390a89c63ceecaf76e45436ea11438
#   Stored in directory: /tmp/pip-ephem-wheel-cache-28ciej8v/wheels/42/68/45/c63edff61c292f2dfd4df4ef6522dcbecc603e7af82813c1d7
# Successfully built transformers
# Installing collected packages: transformers
# Successfully installed transformers-4.32.0.dev0
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: librosa in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (0.10.0.post1)
# Requirement already satisfied: soundfile in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (0.12.1)
# Requirement already satisfied: audioread>=2.1.9 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa) (3.0.0)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa) (1.23.5)
# Requirement already satisfied: scipy>=1.2.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa) (1.3.1)
# Requirement already satisfied: decorator>=4.3.0 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa) (0.56.4)
# Requirement already satisfied: pooch>=1.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa) (1.7.0)
# Requirement already satisfied: soxr>=0.3.2 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa) (0.3.4)
# Requirement already satisfied: typing-extensions>=4.1.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa) (4.7.1)
# Requirement already satisfied: lazy-loader>=0.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from librosa) (0.1)
# Requirement already satisfied: msgpack>=1.0 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from librosa) (1.0.0)
# Requirement already satisfied: cffi>=1.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pycparser in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from numba>=0.51.0->librosa) (0.39.1)
# Requirement already satisfied: setuptools in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from numba>=0.51.0->librosa) (50.3.0)
# Requirement already satisfied: importlib-metadata in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from numba>=0.51.0->librosa) (6.0.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from pooch>=1.0->librosa) (3.1.1)
# Requirement already satisfied: packaging>=20.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from pooch>=1.0->librosa) (23.1)
# Requirement already satisfied: requests>=2.19.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from pooch>=1.0->librosa) (2.28.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from scikit-learn>=0.20.0->librosa) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2020.6.20)
# Requirement already satisfied: zipp>=0.5 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from importlib-metadata->numba>=0.51.0->librosa) (3.3.0)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: evaluate>=0.3.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: datasets>=2.0.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate>=0.3.0) (2.14.1.dev0)
# Requirement already satisfied: numpy>=1.17 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate>=0.3.0) (1.23.5)
# Requirement already satisfied: dill in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate>=0.3.0) (0.3.6)
# Requirement already satisfied: pandas in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate>=0.3.0) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate>=0.3.0) (2.28.2)
# Requirement already satisfied: tqdm>=4.62.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate>=0.3.0) (4.65.0)
# Requirement already satisfied: xxhash in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate>=0.3.0) (3.2.0)
# Requirement already satisfied: multiprocess in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate>=0.3.0) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate>=0.3.0) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate>=0.3.0) (0.16.4)
# Requirement already satisfied: packaging in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate>=0.3.0) (23.1)
# Requirement already satisfied: responses<0.19 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate>=0.3.0) (0.18.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets>=2.0.0->evaluate>=0.3.0) (12.0.1)
# Requirement already satisfied: aiohttp in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets>=2.0.0->evaluate>=0.3.0) (3.8.4)
# Requirement already satisfied: pyyaml>=5.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets>=2.0.0->evaluate>=0.3.0) (6.0)
# Requirement already satisfied: filelock in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from huggingface-hub>=0.7.0->evaluate>=0.3.0) (3.0.12)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from huggingface-hub>=0.7.0->evaluate>=0.3.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from requests>=2.19.0->evaluate>=0.3.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from requests>=2.19.0->evaluate>=0.3.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from requests>=2.19.0->evaluate>=0.3.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from requests>=2.19.0->evaluate>=0.3.0) (2020.6.20)
# Requirement already satisfied: python-dateutil>=2.8.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from pandas->evaluate>=0.3.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from pandas->evaluate>=0.3.0) (2020.1)
# Requirement already satisfied: attrs>=17.3.0 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate>=0.3.0) (20.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate>=0.3.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate>=0.3.0) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate>=0.3.0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate>=0.3.0) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate>=0.3.0) (1.3.1)
# Requirement already satisfied: six>=1.5 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->evaluate>=0.3.0) (1.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: jiwer in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (3.0.2)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jiwer) (8.1.6)
# Requirement already satisfied: rapidfuzz==2.13.7 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jiwer) (2.13.7)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: wandb in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (0.15.6)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from wandb) (8.1.6)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from wandb) (3.1.32)
# Requirement already satisfied: requests<3,>=2.0.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from wandb) (2.28.2)
# Requirement already satisfied: psutil>=5.0.0 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from wandb) (5.7.2)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from wandb) (1.28.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from wandb) (6.0)
# Requirement already satisfied: pathtools in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from wandb) (0.1.2)
# Requirement already satisfied: setproctitle in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from wandb) (1.3.2)
# Requirement already satisfied: setuptools in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from wandb) (50.3.0)
# Requirement already satisfied: appdirs>=1.4.3 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from wandb) (1.4.4)
# Requirement already satisfied: typing-extensions in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from wandb) (4.7.1)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.12.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from wandb) (4.23.4)
# Requirement already satisfied: six>=1.4.0 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from docker-pycreds>=0.4.0->wandb) (1.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (2020.6.20)
# Requirement already satisfied: smmap<6,>=3.0.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.0)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: bitsandbytes in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (0.41.0)
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting bokeh<2.5
#   Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 238.2 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Requirement already satisfied: Jinja2>=2.9 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from bokeh<2.5) (3.1.2)
# Requirement already satisfied: numpy>=1.11.3 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from bokeh<2.5) (1.23.5)
# Requirement already satisfied: packaging>=16.8 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from bokeh<2.5) (23.1)
# Requirement already satisfied: pillow>=7.1.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from bokeh<2.5) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from bokeh<2.5) (6.0)
# Requirement already satisfied: tornado>=5.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from bokeh<2.5) (6.2)
# Requirement already satisfied: typing-extensions>=3.10.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from bokeh<2.5) (4.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from Jinja2>=2.9->bokeh<2.5) (2.0.1)
# Installing collected packages: bokeh
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 3.1.1
#     Uninstalling bokeh-3.1.1:
#       Successfully uninstalled bokeh-3.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# panel 1.2.0 requires bokeh<3.3.0,>=3.1.1, but you have bokeh 2.4.3 which is incompatible.
# Successfully installed bokeh-2.4.3
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: holoviews[recommended] in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (1.16.2)
# Requirement already satisfied: param<3.0,>=1.12.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from holoviews[recommended]) (1.13.0)
# Requirement already satisfied: numpy>=1.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from holoviews[recommended]) (1.23.5)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from holoviews[recommended]) (2.3.2)
# Requirement already satisfied: panel>=0.13.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from holoviews[recommended]) (1.2.0)
# Requirement already satisfied: colorcet in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from holoviews[recommended]) (3.0.1)
# Requirement already satisfied: packaging in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from holoviews[recommended]) (23.1)
# Requirement already satisfied: pandas>=0.20.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from holoviews[recommended]) (1.5.3)
# Requirement already satisfied: ipython>=5.4.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from holoviews[recommended]) (8.11.0)
# Requirement already satisfied: notebook in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from holoviews[recommended]) (6.5.3)
# Requirement already satisfied: matplotlib>=3 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from holoviews[recommended]) (3.7.1)
# Requirement already satisfied: bokeh>=2.4.3 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from holoviews[recommended]) (2.4.3)
# Requirement already satisfied: Jinja2>=2.9 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from bokeh>=2.4.3->holoviews[recommended]) (3.1.2)
# Requirement already satisfied: pillow>=7.1.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from bokeh>=2.4.3->holoviews[recommended]) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from bokeh>=2.4.3->holoviews[recommended]) (6.0)
# Requirement already satisfied: tornado>=5.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from bokeh>=2.4.3->holoviews[recommended]) (6.2)
# Requirement already satisfied: typing-extensions>=3.10.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from bokeh>=2.4.3->holoviews[recommended]) (4.7.1)
# Requirement already satisfied: backcall in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from ipython>=5.4.0->holoviews[recommended]) (0.2.0)
# Requirement already satisfied: decorator in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from ipython>=5.4.0->holoviews[recommended]) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from ipython>=5.4.0->holoviews[recommended]) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from ipython>=5.4.0->holoviews[recommended]) (0.1.6)
# Requirement already satisfied: pickleshare in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from ipython>=5.4.0->holoviews[recommended]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from ipython>=5.4.0->holoviews[recommended]) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from ipython>=5.4.0->holoviews[recommended]) (2.7.1)
# Requirement already satisfied: stack-data in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from ipython>=5.4.0->holoviews[recommended]) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from ipython>=5.4.0->holoviews[recommended]) (5.9.0)
# Requirement already satisfied: pexpect>4.3 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from ipython>=5.4.0->holoviews[recommended]) (4.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from matplotlib>=3->holoviews[recommended]) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from matplotlib>=3->holoviews[recommended]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from matplotlib>=3->holoviews[recommended]) (4.39.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from matplotlib>=3->holoviews[recommended]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from matplotlib>=3->holoviews[recommended]) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from matplotlib>=3->holoviews[recommended]) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from matplotlib>=3->holoviews[recommended]) (5.12.0)
# Requirement already satisfied: pytz>=2020.1 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from pandas>=0.20.0->holoviews[recommended]) (2020.1)
# Collecting bokeh>=2.4.3 (from holoviews[recommended])
#   Downloading bokeh-3.1.1-py3-none-any.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 146.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: xyzservices>=2021.09.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from panel>=0.13.1->holoviews[recommended]) (2023.7.0)
# Requirement already satisfied: markdown in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from panel>=0.13.1->holoviews[recommended]) (3.4.3)
# Requirement already satisfied: markdown-it-py in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from panel>=0.13.1->holoviews[recommended]) (2.2.0)
# Requirement already satisfied: linkify-it-py in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from panel>=0.13.1->holoviews[recommended]) (2.0.2)
# Requirement already satisfied: mdit-py-plugins in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from panel>=0.13.1->holoviews[recommended]) (0.3.3)
# Requirement already satisfied: requests in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from panel>=0.13.1->holoviews[recommended]) (2.28.2)
# Requirement already satisfied: tqdm>=4.48.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from panel>=0.13.1->holoviews[recommended]) (4.65.0)
# Requirement already satisfied: bleach in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from panel>=0.13.1->holoviews[recommended]) (6.0.0)
# Requirement already satisfied: pyct>=0.4.4 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from colorcet->holoviews[recommended]) (0.5.0)
# Requirement already satisfied: pyzmq>=17 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from notebook->holoviews[recommended]) (25.0.1)
# Requirement already satisfied: argon2-cffi in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from notebook->holoviews[recommended]) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from notebook->holoviews[recommended]) (5.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from notebook->holoviews[recommended]) (8.0.3)
# Requirement already satisfied: ipython-genutils in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from notebook->holoviews[recommended]) (0.2.0)
# Requirement already satisfied: nbformat in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from notebook->holoviews[recommended]) (5.7.3)
# Requirement already satisfied: nbconvert>=5 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from notebook->holoviews[recommended]) (7.2.10)
# Requirement already satisfied: nest-asyncio>=1.5 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from notebook->holoviews[recommended]) (1.5.6)
# Requirement already satisfied: ipykernel in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from notebook->holoviews[recommended]) (6.21.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from notebook->holoviews[recommended]) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from notebook->holoviews[recommended]) (0.17.1)
# Requirement already satisfied: prometheus-client in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from notebook->holoviews[recommended]) (0.16.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from notebook->holoviews[recommended]) (0.5.3)
# Requirement already satisfied: zipp>=3.1.0 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=3->holoviews[recommended]) (3.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.4.0->holoviews[recommended]) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from Jinja2>=2.9->bokeh>=2.4.3->holoviews[recommended]) (2.0.1)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jupyter-client>=5.3.4->notebook->holoviews[recommended]) (6.0.0)
# Requirement already satisfied: platformdirs>=2.5 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jupyter-core>=4.6.1->notebook->holoviews[recommended]) (3.1.1)
# Requirement already satisfied: jupyter-server>=1.8 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from nbclassic>=0.4.7->notebook->holoviews[recommended]) (2.5.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from nbclassic>=0.4.7->notebook->holoviews[recommended]) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook->holoviews[recommended]) (4.11.2)
# Requirement already satisfied: defusedxml in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook->holoviews[recommended]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook->holoviews[recommended]) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook->holoviews[recommended]) (2.0.5)
# Requirement already satisfied: nbclient>=0.5.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook->holoviews[recommended]) (0.7.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook->holoviews[recommended]) (1.5.0)
# Requirement already satisfied: tinycss2 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook->holoviews[recommended]) (1.2.1)
# Requirement already satisfied: fastjsonschema in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from nbformat->notebook->holoviews[recommended]) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from nbformat->notebook->holoviews[recommended]) (4.17.3)
# Requirement already satisfied: ptyprocess>=0.5 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.4.0->holoviews[recommended]) (0.6.0)
# Requirement already satisfied: wcwidth in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.4.0->holoviews[recommended]) (0.2.5)
# Requirement already satisfied: six>=1.5 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=3->holoviews[recommended]) (1.15.0)
# Requirement already satisfied: argon2-cffi-bindings in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from argon2-cffi->notebook->holoviews[recommended]) (21.2.0)
# Requirement already satisfied: webencodings in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from bleach->panel>=0.13.1->holoviews[recommended]) (0.5.1)
# Requirement already satisfied: comm>=0.1.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from ipykernel->notebook->holoviews[recommended]) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from ipykernel->notebook->holoviews[recommended]) (1.6.6)
# Requirement already satisfied: psutil in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from ipykernel->notebook->holoviews[recommended]) (5.7.2)
# Requirement already satisfied: uc-micro-py in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from linkify-it-py->panel>=0.13.1->holoviews[recommended]) (1.0.2)
# Requirement already satisfied: mdurl~=0.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from markdown-it-py->panel>=0.13.1->holoviews[recommended]) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from requests->panel>=0.13.1->holoviews[recommended]) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from requests->panel>=0.13.1->holoviews[recommended]) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from requests->panel>=0.13.1->holoviews[recommended]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from requests->panel>=0.13.1->holoviews[recommended]) (2020.6.20)
# Requirement already satisfied: executing>=1.2.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from stack-data->ipython>=5.4.0->holoviews[recommended]) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from stack-data->ipython>=5.4.0->holoviews[recommended]) (2.2.1)
# Requirement already satisfied: pure-eval in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from stack-data->ipython>=5.4.0->holoviews[recommended]) (0.2.2)
# Requirement already satisfied: attrs>=17.4.0 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook->holoviews[recommended]) (20.2.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook->holoviews[recommended]) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook->holoviews[recommended]) (0.17.3)
# Requirement already satisfied: anyio>=3.1.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->holoviews[recommended]) (3.6.2)
# Requirement already satisfied: jupyter-events>=0.4.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->holoviews[recommended]) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->holoviews[recommended]) (0.4.4)
# Requirement already satisfied: websocket-client in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->holoviews[recommended]) (1.5.1)
# Requirement already satisfied: cffi>=1.0.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->holoviews[recommended]) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from beautifulsoup4->nbconvert>=5->notebook->holoviews[recommended]) (2.4)
# Requirement already satisfied: sniffio>=1.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->holoviews[recommended]) (1.3.0)
# Requirement already satisfied: pycparser in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->holoviews[recommended]) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->holoviews[recommended]) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->holoviews[recommended]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->holoviews[recommended]) (0.1.1)
# Requirement already satisfied: fqdn in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook->holoviews[recommended]) (1.5.1)
# Requirement already satisfied: isoduration in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook->holoviews[recommended]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook->holoviews[recommended]) (2.3)
# Requirement already satisfied: uri-template in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook->holoviews[recommended]) (1.2.0)
# Requirement already satisfied: webcolors>=1.11 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat->notebook->holoviews[recommended]) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from isoduration->jsonschema>=2.6->nbformat->notebook->holoviews[recommended]) (1.2.3)
# Installing collected packages: bokeh
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 2.4.3
#     Uninstalling bokeh-2.4.3:
#       Successfully uninstalled bokeh-2.4.3
# Successfully installed bokeh-3.1.1
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: evaluate in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: datasets>=2.0.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate) (2.14.1.dev0)
# Requirement already satisfied: numpy>=1.17 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate) (1.23.5)
# Requirement already satisfied: dill in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate) (0.3.6)
# Requirement already satisfied: pandas in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate) (2.28.2)
# Requirement already satisfied: tqdm>=4.62.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate) (4.65.0)
# Requirement already satisfied: xxhash in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate) (3.2.0)
# Requirement already satisfied: multiprocess in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate) (0.16.4)
# Requirement already satisfied: packaging in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate) (23.1)
# Requirement already satisfied: responses<0.19 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets>=2.0.0->evaluate) (12.0.1)
# Requirement already satisfied: aiohttp in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets>=2.0.0->evaluate) (3.8.4)
# Requirement already satisfied: pyyaml>=5.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: filelock in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from huggingface-hub>=0.7.0->evaluate) (3.0.12)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from requests>=2.19.0->evaluate) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from requests>=2.19.0->evaluate) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from requests>=2.19.0->evaluate) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from requests>=2.19.0->evaluate) (2020.6.20)
# Requirement already satisfied: python-dateutil>=2.8.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from pandas->evaluate) (2020.1)
# Requirement already satisfied: attrs>=17.3.0 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (20.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /mnt/irisgpfs/users/gmenon/.local/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: six>=1.5 in /mnt/irisgpfs/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.15.0)

# %%
# !export LD_LIBRARY_PATH=/usr/local/cuda-12.0/lib64${LD_LIBRARY_PATH:+:${LD_LIBRARY_PATH}}

# %%
# %set_env WANDB_LOG_MODEL=True
# %set_env WANDB_WATCH=all
# %set_env WANDB_NOTEBOOK_NAME=whisper_finetune.ipynb
# Out:
# env: WANDB_LOG_MODEL=True
# env: WANDB_WATCH=all
# env: WANDB_NOTEBOOK_NAME=whisper_finetune.ipynb

# %%
from datasets import Dataset, IterableDatasetDict, load_dataset, interleave_datasets, Audio 
import evaluate

import torch
import string
from dataclasses import dataclass
from typing import Any, Dict, List, Union

from transformers import WhisperForConditionalGeneration
from transformers import WhisperProcessor
from transformers import Seq2SeqTrainingArguments
from transformers import Seq2SeqTrainer
from transformers import WhisperTokenizer
from transformers import WhisperFeatureExtractor
import wandb
from IPython.display import clear_output
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift
import numpy as np
from huggingface_hub import notebook_login
from transformers import TrainerCallback
from transformers.integrations import WandbCallback
from transformers.trainer_pt_utils import IterableDatasetShard
from torch.utils.data import IterableDataset
from datasets import load_dataset, Audio
from pathlib import Path
import numpy as np
import holoviews as hv
import panel as pn
import tempfile
from bokeh.resources import INLINE
hv.extension("bokeh", logo=False)

from io import StringIO
import pandas as pd
import warnings
import jiwer
warnings.filterwarnings('ignore')

clear_output()
torch.cuda.is_available()
# Out:
# ==============================WARNING: DEPRECATED!==============================
# WARNING! This version of bitsandbytes is deprecated. Please switch to `pip install bitsandbytes` and the new repo: https://github.com/TimDettmers/bitsandbytes
# ==============================WARNING: DEPRECATED!==============================
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/transformers/utils/import_utils.py:1125, in _LazyModule._get_module(self, module_name)
#    1124 try:
# -> 1125     return importlib.import_module("." + module_name, self.__name__)
#    1126 except Exception as e:
#
# File /opt/apps/resif/iris-rhel8/2020b/broadwell/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/importlib/__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1014, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:975, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:671, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:783, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:219, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.local/lib/python3.8/site-packages/transformers/trainer_seq2seq.py:25
#      24 from .generation.configuration_utils import GenerationConfig
# ---> 25 from .trainer import Trainer
#      26 from .utils import logging
#
# File ~/.local/lib/python3.8/site-packages/transformers/trainer.py:194
#     193 if is_peft_available():
# --> 194     from peft import PeftModel
#     197 if is_accelerate_available():
#
# File ~/.local/lib/python3.8/site-packages/peft/__init__.py:22
#      20 __version__ = "0.5.0.dev0"
# ---> 22 from .auto import (
#      23     AutoPeftModel,
#      24     AutoPeftModelForCausalLM,
#      25     AutoPeftModelForSequenceClassification,
#      26     AutoPeftModelForSeq2SeqLM,
#      27     AutoPeftModelForTokenClassification,
#      28     AutoPeftModelForQuestionAnswering,
#      29     AutoPeftModelForFeatureExtraction,
#      30 )
#      31 from .mapping import MODEL_TYPE_TO_PEFT_MODEL_MAPPING, PEFT_TYPE_TO_CONFIG_MAPPING, get_peft_config, get_peft_model
#
# File ~/.local/lib/python3.8/site-packages/peft/auto.py:30
#      21 from transformers import (
#      22     AutoModel,
#      23     AutoModelForCausalLM,
#    (...)
#      27     AutoModelForTokenClassification,
#      28 )
# ---> 30 from .mapping import MODEL_TYPE_TO_PEFT_MODEL_MAPPING
#      31 from .peft_model import (
#      32     PeftModel,
#      33     PeftModelForCausalLM,
#    (...)
#      38     PeftModelForTokenClassification,
#      39 )
#
# File ~/.local/lib/python3.8/site-packages/peft/mapping.py:20
#      18 from typing import TYPE_CHECKING, Any, Dict
# ---> 20 from .peft_model import (
#      21     PeftModel,
#      22     PeftModelForCausalLM,
#      23     PeftModelForFeatureExtraction,
#      24     PeftModelForQuestionAnswering,
#      25     PeftModelForSeq2SeqLM,
#      26     PeftModelForSequenceClassification,
#      27     PeftModelForTokenClassification,
#      28 )
#      29 from .tuners import (
#      30     AdaLoraConfig,
#      31     AdaptionPromptConfig,
#    (...)
#      36     PromptTuningConfig,
#      37 )
#
# File ~/.local/lib/python3.8/site-packages/peft/peft_model.py:39
#      38 from . import __version__
# ---> 39 from .tuners import (
#      40     AdaLoraModel,
#      41     AdaptionPromptModel,
#      42     IA3Model,
#      43     LoraModel,
#      44     PrefixEncoder,
#      45     PromptEmbedding,
#      46     PromptEncoder,
#      47 )
#      48 from .utils import (
#      49     SAFETENSORS_WEIGHTS_NAME,
#      50     TRANSFORMERS_MODELS_TO_PREFIX_TUNING_POSTPROCESS_MAPPING,
#    (...)
#      63     shift_tokens_right,
#      64 )
#
# File ~/.local/lib/python3.8/site-packages/peft/tuners/__init__.py:21
#      20 from .adaption_prompt import AdaptionPromptConfig, AdaptionPromptModel
# ---> 21 from .lora import LoraConfig, LoraModel
#      22 from .ia3 import IA3Config, IA3Model
#
# File ~/.local/lib/python3.8/site-packages/peft/tuners/lora.py:1056
#    1054 if is_bnb_available():
# -> 1056     class Linear8bitLt(bnb.nn.Linear8bitLt, LoraLayer):
#    1057         # Lora implemented in a dense layer
#    1058         def __init__(
#    1059             self,
#    1060             adapter_name,
#    (...)
#    1066             **kwargs,
#    1067         ):
#
# AttributeError: module 'bitsandbytes.nn' has no attribute 'Linear8bitLt'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 12
#      10 from transformers import WhisperProcessor
#      11 from transformers import Seq2SeqTrainingArguments
# ---> 12 from transformers import Seq2SeqTrainer
#      13 from transformers import WhisperTokenizer
#      14 from transformers import WhisperFeatureExtractor
#
# File <frozen importlib._bootstrap>:1039, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~/.local/lib/python3.8/site-packages/transformers/utils/import_utils.py:1115, in _LazyModule.__getattr__(self, name)
#    1113     value = self._get_module(name)
#    1114 elif name in self._class_to_module.keys():
# -> 1115     module = self._get_module(self._class_to_module[name])
#    1116     value = getattr(module, name)
#    1117 else:
#
# File ~/.local/lib/python3.8/site-packages/transformers/utils/import_utils.py:1127, in _LazyModule._get_module(self, module_name)
#    1125     return importlib.import_module("." + module_name, self.__name__)
#    1126 except Exception as e:
# -> 1127     raise RuntimeError(
#    1128         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1129         f" traceback):\n{e}"
#    1130     ) from e
#
# RuntimeError: Failed to import transformers.trainer_seq2seq because of the following error (look up to see its traceback):
# module 'bitsandbytes.nn' has no attribute 'Linear8bitLt'

# %%
! python -m bitsandbytes
# Out:
# ==============================WARNING: DEPRECATED!==============================
# WARNING! This version of bitsandbytes is deprecated. Please switch to `pip install bitsandbytes` and the new repo: https://github.com/TimDettmers/bitsandbytes
# ==============================WARNING: DEPRECATED!==============================
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++ BUG REPORT INFORMATION ++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# ++++++++++++++++++ /usr/local CUDA PATHS +++++++++++++++++++
#
#
# +++++++++++++++ WORKING DIRECTORY CUDA PATHS +++++++++++++++
#
#
# ++++++++++++++++++ LD_LIBRARY CUDA PATHS +++++++++++++++++++
# ++++++++++++ /local/cuda-12.0/lib64 CUDA PATHS +++++++++++++
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/XZ/5.2.5-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/skylake/software/x265/3.3-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/zlib/1.2.11-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/binutils/2.35-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/skylake/software/FFmpeg/4.3.1-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/ncurses/6.2-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/libreadline/8.0-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/util-linux/2.36-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/bzip2/1.0.8-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/libpciaccess/0.16-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/skylake/software/x264/20201026-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/Brotli/1.0.9-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/X11/20201008-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/expat/2.2.9-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/GMP/6.2.0-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/Tcl/8.6.10-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/GCCcore/10.2.0/lib64 CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/libpng/1.6.37-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/fontconfig/2.13.92-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/SQLite/3.33.0-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/FriBidi/1.0.10-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/skylake/software/LAME/3.100-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/freetype/2.10.3-GCCcore-10.2.0/lib CUDA PATHS
#
#  /opt/apps/resif/iris-rhel8/2020b/gpu/software/libffi/3.3-GCCcore-10.2.0/lib64 CUDA PATHS
#
#
# Traceback (most recent call last):
#   File "/opt/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/opt/apps/resif/iris-rhel8/2020b/gpu/software/Python/3.8.6-GCCcore-10.2.0/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/users/gmenon/.local/lib/python3.8/site-packages/bitsandbytes/__main__.py", line 99, in <module>
#     from . import COMPILED_WITH_CUDA, PACKAGE_GITHUB_URL
# ImportError: cannot import name 'COMPILED_WITH_CUDA' from 'bitsandbytes' (/home/users/gmenon/.local/lib/python3.8/site-packages/bitsandbytes/__init__.py)

# %%
run = wandb.init(project="whisper_finetuning", job_type="fine-tuning", group="trial",)

# %%
song_metadata = pd.read_csv("/home/users/gmenon/notebooks/home/users/gmenon/notebooks/song_metadata_cleaned.csv")
from ftlangdetect import detect

def is_english(text: str) -> str:
    """Simple Function to detect whether the language of the text is english or not.
    Returns a Boolean output for the same.Input the text column"""
    return detect(text, low_memory=True)["lang"]

chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"\%\$\&\^\*\@\#\<\>\/\+\\=\_\\}\{\)\(\]\[\`1234567890]'
song_metadata["transcription"] = song_metadata["transcription"].replace(chars_to_ignore_regex, '', regex=True)
song_metadata = song_metadata[song_metadata.transcription.str.len()>8]
song_metadata["language"] = song_metadata["transcription"].apply(is_english)
song_metadata = song_metadata.loc[song_metadata["language"] == "en"]
song_metadata = song_metadata[['file_name','transcription']].head(1000)
song_metadata

# %%
from datasets import load_dataset,Dataset, Audio
#audio_dataset = Dataset.from_dict({"audio": list(dali_info['AUDIO_PATH'])}).cast_column("audio", Audio())

audio_dataset = Dataset.from_dict({"audio": list(song_metadata["file_name"]), "transcription": list(song_metadata["transcription"])}).cast_column("audio", Audio(sampling_rate=16000))
audio_dataset = audio_dataset.train_test_split(test_size=0.2, shuffle=True)
audio_dataset

# %%
import torch
torch.cuda.empty_cache()

# %%
augment_waveform = Compose([
    AddGaussianNoise(min_amplitude=0.005, max_amplitude=0.015, p=0.3),
    TimeStretch(min_rate=0.8, max_rate=1.25, p=0.3, leave_length_unchanged=False),
    PitchShift(min_semitones=-4, max_semitones=4, p=0.3)
    ,])

def augment_dataset(batch):

    audio = batch["audio"]["array"]
    # apply augmentation
    augmented_audio = augment_waveform(samples=audio, sample_rate=16000)

    batch["audio"]["array"] = augmented_audio

    return batch


# call augment dataset on the training set
audio_dataset["train"] = audio_dataset["train"].map(augment_dataset)

# %%
feature_extractor = WhisperFeatureExtractor.from_pretrained(
    "openai/whisper-base"
)
tokenizer = WhisperTokenizer.from_pretrained(
    "openai/whisper-base", 
     language="English",
     task="transcribe",
     model_max_length=225
)
processor = WhisperProcessor.from_pretrained(
    "openai/whisper-base",
     language="English", 
     task="transcribe",
     model_max_length=225
)

# %%
def fix_sentence(sentence):
    transcription = sentence
  
    if transcription.startswith('"') and transcription.endswith('"'):
        # we can remove trailing quotation marks as they do not affect the transcription
        transcription = transcription[1:-1]
  
    if transcription[-1] not in [".", "?", "!"]:
        # append a full-stop to sentences that do not end in punctuation
        transcription = transcription + "."
    transcription = transcription[:-1].translate(str.maketrans('', '', string.punctuation)) + transcription[-1]
    return transcription
    
def prepare_dataset(examples):
    # compute log-Mel input features from input audio array 
    audio = examples["audio"]
    
    examples["input_features"] = feature_extractor(
        audio["array"], sampling_rate=16000).input_features[0]
    
    sentences = fix_sentence(examples["transcription"])
    
    # encode target text to label ids 
    examples["labels"] = tokenizer(sentences, max_length=225, truncation=True).input_ids
    return examples


def filter_empty_strings(sentence):
    if len(sentence) < 2:
        return False
    else: return True

# %%
for k in audio_dataset:
    audio_dataset[k] = audio_dataset[k].filter(filter_empty_strings, input_columns=["transcription"])

# %%
for i,k in enumerate(audio_dataset["train"]):
    print(k)
    if i == 3:
        break

# %%
for k in audio_dataset:
    audio_dataset[k] = audio_dataset[k].map(prepare_dataset,num_proc = 14).with_format("torch")

# %%
audio_dataset["train"] = audio_dataset["train"].shuffle(seed=500)

# %%
@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lengths and need different padding methods
        # first treat the audio inputs by simply returning torch tensors
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        # get the tokenized label sequences
        label_features = [{"input_ids": self.processor.tokenizer.truncate_sequences(feature["labels"])[0]}
                          for feature in features]
        # pad the labels to max length
        
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt",)

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        # if bos token is appended in previous tokenization step,
        # cut bos token here as it's append later anyways
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# %%
metric = evaluate.load("wer")

# evaluate with the 'normalised' WER
do_normalize_eval = True


def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids

    # replace -100 with the pad_token_id
    label_ids[label_ids == -100] = processor.tokenizer.pad_token_id

    # we do not want to group tokens when computing the metrics
    pred_str = processor.tokenizer.batch_decode(pred_ids, skip_special_tokens=True, normalize=do_normalize_eval)
    label_str = processor.tokenizer.batch_decode(label_ids, skip_special_tokens=True, normalize=do_normalize_eval)

    wer = 100 * metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-base", use_cache=False)
model.config.forced_decoder_ids = None
model.config.suppress_tokens = []
model.config.use_cache = False

# %%
# trainer callback to reinitialise and reshuffle the streamable datasets at the beginning of each epoch
class ShuffleCallback(TrainerCallback):
    def on_epoch_begin(self, args, state, control, train_dataloader, **kwargs):
        if isinstance(train_dataloader.dataset, IterableDatasetShard):
            pass  # set_epoch() is handled by the Trainer
        elif isinstance(train_dataloader.dataset, IterableDataset):
            train_dataloader.dataset.set_epoch(train_dataloader.dataset._epoch + 1)

# %%
def load_samples_dataset(dataset, num_samples=100):
    samples = []
    for i, item in enumerate(dataset):
        samples.append(item)
        if i == (num_samples-1):
            break
    sample_dataset = Dataset.from_list(samples)
    return sample_dataset

def compute_spectrograms(example):
    waveform =  example["audio"]["array"]
    specs = feature_extractor(waveform, sampling_rate=16000, padding="do_not_pad").input_features[0]
    return {"spectrogram": specs}


def record_to_html(sample_record):
    audio_array = np.array(sample_record["audio"]["array"])
    audio_sr = sample_record["audio"]["sampling_rate"]
    length = sample_record.get("length")
    if length:
        audio_duration = length
    else:
        sample_record["length"] = audio_duration = len(audio_array)/audio_sr
    audio_duration = sample_record["length"]
    audio_spectrogram = np.array(sample_record["spectrogram"])

    bounds = (0,0, audio_duration, audio_spectrogram.max())

    waveform_int = np.int16(audio_array * 32767)

    
    
    hv_audio = pn.pane.Audio(waveform_int, sample_rate=audio_sr, name='Audio', throttle=500)
    
    slider = pn.widgets.FloatSlider(end=audio_duration, visible=False, step=0.001)
    line_audio = hv.VLine(0).opts(color='black')
    line_spec = hv.VLine(0).opts(color='red')
    
    
    slider.jslink(hv_audio, value='time', bidirectional=True)
    slider.jslink(line_audio, value='glyph.location')
    slider.jslink(line_spec, value='glyph.location')
    
    time = np.linspace(0, audio_duration, num=len(audio_array))
    line_plot_hv = hv.Curve(
        (time, audio_array), ["Time (s)", "amplitude"]).opts(
        width=500, height=150, axiswise=True) * line_audio
    
    hv_spec_gram = hv.Image(
        audio_spectrogram, bounds=(bounds), kdims=["Time (s)", "Frequency (hz)"]).opts(
        width=500, height=150, labelled=[], axiswise=True, color_levels=512)* line_spec
    
    
    combined = pn.Row(hv_audio, hv_spec_gram, line_plot_hv, slider)
    audio_html = StringIO()
    combined.save(audio_html)
    sample_record["audio_with_spec"] = audio_html
    return sample_record


def dataset_to_records(dataset):
    records = []
    for item in dataset:
        record = {}
        sample_record = record_to_html(item)
        record["audio_with_spec"] = wandb.Html(sample_record["audio_with_spec"])
        record["transcription"] = sample_record["transcription"]
        record["length"] =  sample_record["length"]
        records.append(record)
    records = pd.DataFrame(records)
    return records
    
def decode_predictions(trainer, predictions):
    pred_ids = predictions.predictions
    pred_str = trainer.tokenizer.batch_decode(pred_ids, skip_special_tokens=True, )
    return pred_str


def compute_measures(predictions, labels):
    measures = [jiwer.compute_measures(ls, ps) for ps, ls in zip(predictions, labels)]
    measures_df = pd.DataFrame(measures)[["wer", "hits", "substitutions", "deletions", "insertions"]]
    return measures_df

class WandbProgressResultsCallback(WandbCallback):
    def __init__(self, trainer, sample_dataset): 
        super().__init__()
        self.trainer = trainer
        self.sample_dataset = sample_dataset
        self.records_df = dataset_to_records(sample_dataset)
        
    def on_log(self, args, state, control, model=None, logs=None, **kwargs):
        super().on_log(args, state, control, model, logs)
        predictions = trainer.predict(self.sample_dataset)
        predictions = decode_predictions(self.trainer, predictions)
        measures_df = compute_measures(predictions, self.records_df["transcription"].tolist())
        records_df = pd.concat([self.records_df, measures_df], axis=1)
        records_df["prediction"] = predictions
        records_df["step"] = state.global_step
        records_table = self._wandb.Table(dataframe=records_df)
        self._wandb.log({"sample_predictions": records_table})
        
    def on_save(self, args, state, control, model=None, tokenizer=None, **kwargs):
        if self._wandb is None:
            return
        if self._log_model and self._initialized and state.is_world_process_zero:
            with tempfile.TemporaryDirectory() as temp_dir:

                self.trainer.save_model(temp_dir)
                metadata = (
                    {
                        k: v
                        for k, v in dict(self._wandb.summary).items()
                        if isinstance(v, numbers.Number) and not k.startswith("_")
                    }
                    if not args.load_best_model_at_end
                    else {
                        f"eval/{args.metric_for_best_model}": state.best_metric,
                        "train/total_floss": state.total_flos,
                    }
                )
                artifact = self._wandb.Artifact(
                    name=f"model-{self._wandb.run.id}",
                    type="model", metadata=metadata)
                for f in Path(temp_dir).glob("*"):
                    if f.is_file():
                        with artifact.new_file(f.name, mode="wb") as fa:
                            fa.write(f.read_bytes())
                self._wandb.run.log_artifact(artifact)

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="../model/whisper-base-finetuned",  # change to a repo name of your choice
    per_device_train_batch_size=4,
    gradient_accumulation_steps=1,  # increase by 2x for every 2x decrease in batch size
    learning_rate=1e-5,
    save_total_limit=4,
    warmup_steps=500,
    max_steps=5000,
    gradient_checkpointing=True,
    fp16=True,
#     fp16_full_eval=True,
    optim="adamw_bnb_8bit",
    evaluation_strategy="steps",
    per_device_eval_batch_size=64,
    predict_with_generate=True,
    generation_max_length=225,
    save_steps=500,
    eval_steps=500,
    logging_steps=250,
    report_to="none",
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    hub_strategy="checkpoint",
    push_to_hub=True,
    remove_unused_columns=False, 
    ignore_data_skip=True
)

# %%
samples_dataset = load_samples_dataset(audio_dataset["test"]).map(compute_spectrograms)

# %%
trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=audio_dataset["train"],
    eval_dataset=samples_dataset,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=processor,
    callbacks=[ShuffleCallback(), ],
    
)

# %%
progress_callback = WandbProgressResultsCallback(trainer, samples_dataset)
clear_output()

# %%
trainer.add_callback(progress_callback)

# %%
model.save_pretrained(training_args.output_dir)
processor.save_pretrained(training_args.output_dir)

# %%
trainer.train()

# %%
kwargs = {
    "language": "en",
    "model_name": "Whisper Base Finetuning",  
    "finetuned_from": "openai/whisper-base",
    "tasks": "automatic-lyrics-transcription",
    "tags": "whisper-learning",
}

# %%
trainer.push_to_hub(**kwargs)

# %%
wandb.finish()

# %% [markdown]
# ---

# %%
# Out:
#   Cell In[1], line 1
#     ---
#        ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from datasets import load_dataset,Dataset, Audio
from transformers import WhisperTokenizer
from transformers import WhisperFeatureExtractor
from datasets import Audio
from transformers import WhisperProcessor
import torch
from dataclasses import dataclass
from typing import Any, Dict, List, Union
from datasets import load_metric
from transformers import WhisperForConditionalGeneration
from transformers import Seq2SeqTrainingArguments
from transformers import Seq2SeqTrainer


song_metadata = pd.read_csv("/home/users/gmenon/notebooks/home/users/gmenon/notebooks/song_metadata_cleaned.csv")
from ftlangdetect import detect

def is_english(text: str) -> str:
    """Simple Function to detect whether the language of the text is english or not.
    Returns a Boolean output for the same.Input the text column"""
    return detect(text, low_memory=True)["lang"]

def prepare_dataset(batch):
    audio = batch["audio"]
    batch["input_features"] = feature_extractor(audio["array"], sampling_rate=audio["sampling_rate"]).input_features[0]
    batch["labels"] = tokenizer(batch["sentence"]).input_ids
    return batch

def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids
    label_ids[label_ids == -100] = tokenizer.pad_token_id
    pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
    label_str = tokenizer.batch_decode(label_ids, skip_special_tokens=True)
    wer = 100 * metric.compute(predictions=pred_str, references=label_str)
    return {"wer": wer}

@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any
    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]
        batch["labels"] = labels
        return batch


chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"\%\$\&\^\*\@\#\<\>\/\+\\=\_\\}\{\)\(\]\[\`1234567890]'
song_metadata["transcription"] = song_metadata["transcription"].replace(chars_to_ignore_regex, '', regex=True)
song_metadata = song_metadata[song_metadata.transcription.str.len()>8]
song_metadata["language"] = song_metadata["transcription"].apply(is_english)
song_metadata = song_metadata.loc[song_metadata["language"] == "en"]
audio_dataset = Dataset.from_dict({"audio": list(song_metadata["file_name"]), "sentence": list(song_metadata["transcription"])}).cast_column("audio", Audio(sampling_rate=16000))
audio_dataset = audio_dataset.train_test_split(test_size=0.2, shuffle=True)
tokenizer = WhisperTokenizer.from_pretrained("openai/whisper-medium.en", language="English", task="transcribe")
feature_extractor = WhisperFeatureExtractor.from_pretrained("openai/whisper-medium.en")
processor = WhisperProcessor.from_pretrained("openai/whisper-medium.en", language="English", task="transcribe")
audio_dataset = audio_dataset.cast_column("audio", Audio(sampling_rate=16000))
data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)
metric = load_metric("wer")
model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-medium.en")
data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)
metric = load_metric("wer")
model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-medium.en")
model.config.forced_decoder_ids = None
model.config.suppress_tokens = []
training_args = Seq2SeqTrainingArguments(
    output_dir="whisper-small-dali_v2",  # change to a repo name of your choice
    per_device_train_batch_size=4,
    gradient_accumulation_steps=1,  # increase by 2x for every 2x decrease in batch size
    learning_rate=1e-5,
    warmup_steps=500,
    max_steps=1500,
    gradient_checkpointing=True,
    fp16=True,
    evaluation_strategy="steps",
    per_device_eval_batch_size=4,
    predict_with_generate=True,
    generation_max_length=225,
    save_steps=1000,
    eval_steps=1000,
    logging_steps=25,
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    push_to_hub=True,
    resume_from_checkpoint=True
)
trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=audio_dataset["train"],
    eval_dataset=audio_dataset["test"],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=processor.feature_extractor,
)
processor.save_pretrained(training_args.output_dir)
trainer.train(resume_from_checkpoint = False)
# Out:
# /mnt/irisgpfs/users/gmenon/workspace/songsLyricsGenerator/src/notebooks/whisper-small-dali_v2 is already a clone of https://huggingface.co/gmenon/whisper-small-dali_v2. Make sure you pull the latest changes with `repo.git_pull()`.
# /home/users/gmenon/.local/lib/python3.8/site-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# /home/users/gmenon/.local/lib/python3.8/site-packages/datasets/formatting/formatting.py:100: RuntimeWarning: divide by zero encountered in remainder
#   return table.fast_gather(key % table.num_rows)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 105
#      95 trainer = Seq2SeqTrainer(
#      96     args=training_args,
#      97     model=model,
#    (...)
#     102     tokenizer=processor.feature_extractor,
#     103 )
#     104 processor.save_pretrained(training_args.output_dir)
# --> 105 trainer.train(resume_from_checkpoint = False)
#
# File ~/.local/lib/python3.8/site-packages/transformers/trainer.py:1532, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1527     self.model_wrapped = self.model
#    1529 inner_training_loop = find_executable_batch_size(
#    1530     self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1531 )
# -> 1532 return inner_training_loop(
#    1533     args=args,
#    1534     resume_from_checkpoint=resume_from_checkpoint,
#    1535     trial=trial,
#    1536     ignore_keys_for_eval=ignore_keys_for_eval,
#    1537 )
#
# File ~/.local/lib/python3.8/site-packages/transformers/trainer.py:1783, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1780     rng_to_sync = True
#    1782 step = -1
# -> 1783 for step, inputs in enumerate(epoch_iterator):
#    1784     total_batched_samples += 1
#    1785     if rng_to_sync:
#
# File ~/.local/lib/python3.8/site-packages/accelerate/data_loader.py:384, in DataLoaderShard.__iter__(self)
#     382 # We iterate one batch ahead to check when we are at the end
#     383 try:
# --> 384     current_batch = next(dataloader_iter)
#     385 except StopIteration:
#     386     yield
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py:634, in _BaseDataLoaderIter.__next__(self)
#     631 if self._sampler_iter is None:
#     632     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     633     self._reset()  # type: ignore[call-arg]
# --> 634 data = self._next_data()
#     635 self._num_yielded += 1
#     636 if self._dataset_kind == _DatasetKind.Iterable and \
#     637         self._IterableDataset_len_called is not None and \
#     638         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py:678, in _SingleProcessDataLoaderIter._next_data(self)
#     676 def _next_data(self):
#     677     index = self._next_index()  # may raise StopIteration
# --> 678     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     679     if self._pin_memory:
#     680         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/.local/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:49, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      47 if self.auto_collation:
#      48     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
#      51         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File ~/.local/lib/python3.8/site-packages/datasets/arrow_dataset.py:2807, in Dataset.__getitems__(self, keys)
#    2805 def __getitems__(self, keys: List) -> List:
#    2806     """Can be used to get a batch using a list of integers indices."""
# -> 2807     batch = self.__getitem__(keys)
#    2808     n_examples = len(batch[next(iter(batch))])
#    2809     return [{col: array[i] for col, array in batch.items()} for i in range(n_examples)]
#
# File ~/.local/lib/python3.8/site-packages/datasets/arrow_dataset.py:2803, in Dataset.__getitem__(self, key)
#    2801 def __getitem__(self, key):  # noqa: F811
#    2802     """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 2803     return self._getitem(key)
#
# File ~/.local/lib/python3.8/site-packages/datasets/arrow_dataset.py:2787, in Dataset._getitem(self, key, **kwargs)
#    2785 format_kwargs = format_kwargs if format_kwargs is not None else {}
#    2786 formatter = get_formatter(format_type, features=self._info.features, **format_kwargs)
# -> 2787 pa_subtable = query_table(self._data, key, indices=self._indices if self._indices is not None else None)
#    2788 formatted_output = format_table(
#    2789     pa_subtable, key, formatter=formatter, format_columns=format_columns, output_all_columns=output_all_columns
#    2790 )
#    2791 return formatted_output
#
# File ~/.local/lib/python3.8/site-packages/datasets/formatting/formatting.py:588, in query_table(table, key, indices)
#     586     pa_subtable = _query_table(table, key)
#     587 else:
# --> 588     pa_subtable = _query_table_with_indices_mapping(table, key, indices=indices)
#     589 return pa_subtable
#
# File ~/.local/lib/python3.8/site-packages/datasets/formatting/formatting.py:75, in _query_table_with_indices_mapping(table, key, indices)
#      73     return _query_table(table, indices.column(0).to_pylist())
#      74 if isinstance(key, Iterable):
# ---> 75     return _query_table(table, [indices.fast_slice(i, 1).column(0)[0].as_py() for i in key])
#      77 _raise_bad_key_type(key)
#
# File ~/.local/lib/python3.8/site-packages/datasets/formatting/formatting.py:100, in _query_table(table, key)
#      98         return table.table.slice(0, 0)
#      99     # don't use pyarrow.Table.take even for pyarrow >=1.0 (see https://issues.apache.org/jira/browse/ARROW-9773)
# --> 100     return table.fast_gather(key % table.num_rows)
#     102 _raise_bad_key_type(key)
#
# File ~/.local/lib/python3.8/site-packages/datasets/table.py:134, in IndexedTableMixin.fast_gather(self, indices)
#     131     raise ValueError("Indices must be non-empty")
#     132 batch_indices = np.searchsorted(self._offsets, indices, side="right") - 1
#     133 return pa.Table.from_batches(
# --> 134     [
#     135         self._batches[batch_idx].slice(i - self._offsets[batch_idx], 1)
#     136         for batch_idx, i in zip(batch_indices, indices)
#     137     ],
#     138     schema=self._schema,
#     139 )
#
# File ~/.local/lib/python3.8/site-packages/datasets/table.py:135, in <listcomp>(.0)
#     131     raise ValueError("Indices must be non-empty")
#     132 batch_indices = np.searchsorted(self._offsets, indices, side="right") - 1
#     133 return pa.Table.from_batches(
#     134     [
# --> 135         self._batches[batch_idx].slice(i - self._offsets[batch_idx], 1)
#     136         for batch_idx, i in zip(batch_indices, indices)
#     137     ],
#     138     schema=self._schema,
#     139 )
#
# IndexError: list index out of range
